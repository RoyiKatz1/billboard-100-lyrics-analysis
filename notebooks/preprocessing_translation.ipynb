# %% [markdown]
# # Preprocessing for word binding
#
# This notebook:
#
# 1. **Loaded** the Billboard Hot 100 dataset (`dataset.xlsx`).
# 2. **Deduplicated** to unique songs.
# 3. **Detected languages** using a unique-word fingerprint trick.
# 4. **Translated** non-English lyrics to English, with caching & error-handling.
# 5. **Saved** the fully translated corpus to `data/hot100_translated.xlsx`.

# %%
# ──────────────────────────────────────────────
# 1  |  Imports & global config
# ──────────────────────────────────────────────
import re
from pathlib import Path
from typing import List, Dict

import pandas as pd
from tqdm.auto import tqdm
from langdetect import detect, DetectorFactory
from deep_translator import GoogleTranslator     # or use DeepL

import time
import logging

import spacy
nlp_en = spacy.load("en_core_web_sm", disable=["parser", "ner"])

tqdm.pandas()
DetectorFactory.seed = 42                        # reproducible language picks

# %%
# ──────────────────────────────────────────────
# 2  |  Load dataset
# ──────────────────────────────────────────────
DATA_PATH = Path("../data/processed/dataset.xlsx")

df_raw = pd.read_excel(DATA_PATH)
df_raw
# Out:
#             date  rank                              title  \
# 0     2024-12-28     1    All I Want For Christmas Is You
# 1     2024-12-28     2  Rockin' Around The Christmas Tree
# 2     2024-12-28     3                     Last Christmas
# 3     2024-12-28     4                   Jingle Bell Rock
# 4     2024-12-28     5            A Holly Jolly Christmas
# ...          ...   ...                                ...
# 5195  2024-01-06    96                 El Amor de Su Vida
# 5196  2024-01-06    97               Standing Next To You
# 5197  2024-01-06    98                     Man Made A Bar
# 5198  2024-01-06    99                           Que Onda
# 5199  2024-01-06   100                       Great Gatsby
#
#                                       artist  \
# 0                               Mariah Carey
# 1                                 Brenda Lee
# 2                                      Wham!
# 3                                Bobby Helms
# 4                                  Burl Ives
# ...                                      ...
# 5195            Grupo Frontera & Grupo Firme
# 5196                               Jung Kook
# 5197     Morgan Wallen Featuring Eric Church
# 5198  Calle 24 x Chino Pacas x Fuerza Regida
# 5199                                Rod Wave
#
#                                                   image  peakPos  lastpos  \
# 0     https://charts-static.billboard.com/img/1994/1...        1        1
# 1     https://charts-static.billboard.com/img/1960/1...        1        2
# 2     https://charts-static.billboard.com/img/1998/0...        3        4
# 3     https://charts-static.billboard.com/img/1958/1...        3        3
# 4     https://charts-static.billboard.com/img/1998/0...        4        5
# ...                                                 ...      ...      ...
# 5195  https://charts-static.billboard.com/img/2023/0...       68        0
# 5196  https://charts-static.billboard.com/img/2023/1...        5       79
# 5197  https://charts-static.billboard.com/img/2023/0...       15        0
# 5198  https://charts-static.billboard.com/img/2023/0...       61       98
# 5199  https://charts-static.billboard.com/img/2019/0...       30       99
#
#       weeks  isNew                                            song_id  \
# 0        70  False      all_i_want_for_christmas_is_you__mariah_carey
# 1        63  False       rockin_around_the_christmas_tree__brenda_lee
# 2        44  False                               last_christmas__wham
# 3        60  False                      jingle_bell_rock__bobby_helms
# 4        44  False                 a_holly_jolly_christmas__burl_ives
# ...     ...    ...                                                ...
# 5195     16  False    el_amor_de_su_vida__grupo_frontera__grupo_firme
# 5196      8  False                    standing_next_to_you__jung_kook
# 5197     14  False  man_made_a_bar__morgan_wallen_featuring_eric_c...
# 5198     13  False   que_onda__calle_24_x_chino_pacas_x_fuerza_regida
# 5199     14  False                             great_gatsby__rod_wave
#
#                                                  lyrics
# 0     i don't want a lot for christmas there is just...
# 1     rockin' around the christmas tree at the chris...
# 2     ah, ah-ah ooh-woah oh-oh last christmas, i gav...
# 3     jingle bell, jingle bell, jingle bell rock jin...
# 4     ding-dong-ding ding-dong-ding have a holly jol...
# ...                                                 ...
# 5195  si estoy tomando es porque estoy echando alcoh...
# 5196  standing next to you play me slow push up on t...
# 5197  i sat down on a barstool, like a dern fool 'ca...
# 5198  baby, me vuelves loco no se esperó al hotel y ...
# 5199  i tell myself, "it'll be alright" now it's 3 a...
#
# [5200 rows x 11 columns]

# %%
# ──────────────────────────────────────────────
# 3  |  Drop duplicate songs
# ──────────────────────────────────────────────

df = df_raw.copy()

df = (
    df.drop_duplicates(subset="song_id", keep="first")
      .reset_index(drop=True)
)
df = df[df["lyrics"].notna()]

df
# Out:
#            date  rank                                              title  \
# 0    2024-12-28     1                    All I Want For Christmas Is You
# 1    2024-12-28     2                  Rockin' Around The Christmas Tree
# 2    2024-12-28     3                                     Last Christmas
# 3    2024-12-28     4                                   Jingle Bell Rock
# 4    2024-12-28     5                            A Holly Jolly Christmas
# ..          ...   ...                                                ...
# 756  2024-01-06    43                    I Saw Mommy Kissing Santa Claus
# 757  2024-01-06    46                                    Merry Christmas
# 758  2024-01-06    50  (There's No Place Like) Home For The Holidays ...
# 759  2024-01-06    87                                  Winter Wonderland
# 760  2024-01-06    90                           DJ Play A Christmas Song
#
#                                                artist  \
# 0                                        Mariah Carey
# 1                                          Brenda Lee
# 2                                               Wham!
# 3                                         Bobby Helms
# 4                                           Burl Ives
# ..                                                ...
# 756                                         Jackson 5
# 757                           Ed Sheeran & Elton John
# 758  Perry Como With Mitchell Ayers And His Orchestra
# 759                                             Chloe
# 760                                              Cher
#
#                                                  image  peakPos  lastpos  \
# 0    https://charts-static.billboard.com/img/1994/1...        1        1
# 1    https://charts-static.billboard.com/img/1960/1...        1        2
# 2    https://charts-static.billboard.com/img/1998/0...        3        4
# 3    https://charts-static.billboard.com/img/1958/1...        3        3
# 4    https://charts-static.billboard.com/img/1998/0...        4        5
# ..                                                 ...      ...      ...
# 756  https://charts-static.billboard.com/img/1969/1...       43        0
# 757  https://charts-static.billboard.com/img/2021/1...       42        0
# 758  https://charts-static.billboard.com/img/2005/1...       50        0
# 759  https://charts-static.billboard.com/img/2023/1...       87       96
# 760  https://charts-static.billboard.com/img/2023/1...       90       94
#
#      weeks  isNew                                            song_id  \
# 0       70  False      all_i_want_for_christmas_is_you__mariah_carey
# 1       63  False       rockin_around_the_christmas_tree__brenda_lee
# 2       44  False                               last_christmas__wham
# 3       60  False                      jingle_bell_rock__bobby_helms
# 4       44  False                 a_holly_jolly_christmas__burl_ives
# ..     ...    ...                                                ...
# 756      1   True         i_saw_mommy_kissing_santa_claus__jackson_5
# 757      7  False            merry_christmas__ed_sheeran__elton_john
# 758      1   True  theres_no_place_like_home_for_the_holidays_195...
# 759      2  False                           winter_wonderland__chloe
# 760      2  False                     dj_play_a_christmas_song__cher
#
#                                                 lyrics
# 0    i don't want a lot for christmas there is just...
# 1    rockin' around the christmas tree at the chris...
# 2    ah, ah-ah ooh-woah oh-oh last christmas, i gav...
# 3    jingle bell, jingle bell, jingle bell rock jin...
# 4    ding-dong-ding ding-dong-ding have a holly jol...
# ..                                                 ...
# 756  wow! mommy's kissing santa claus! i saw mommy ...
# 757  build the fire and gather 'round the tree fill...
# 758  oh, there's no place like home for the holiday...
# 759  walk walk, walk, walking walk, walk, walking w...
# 760  no one on the streets and the city is quiet i ...
#
# [758 rows x 11 columns]

# %%
# ──────────────────────────────────────────────
# 4  |  Language detection
# ──────────────────────────────────────────────
def guess_lang(text: str) -> str:
    try:
        return detect(text)
    except:
        return "un"

df["orig_lang"] = df["lyrics"].progress_apply(guess_lang)
df["orig_lang"].value_counts()
# Out:
#   0%|          | 0/758 [00:00<?, ?it/s]
# orig_lang
# en    644
# es     56
# ru     19
# pt     15
# tr      5
# de      5
# pl      3
# th      2
# nl      2
# uk      1
# ja      1
# ar      1
# fr      1
# sv      1
# hu      1
# un      1
# Name: count, dtype: int64

# %% [markdown]
# As we can see - there are a lot of spanish songs that will need translation, but there are other songs in a variety of languages that seem suspicious - let's check it out

# %%
weird_lang = df[~df["orig_lang"].isin(["en", "es"])]
weird_lang[["title", "artist", "lyrics", "orig_lang"]]
# Out:
#                         title  \
# 10                     Luther
# 11                     TV Off
# 31                   Timeless
# 58            Defying Gravity
# 110         AGATS2 (Insecure)
# 113  No One Mourns The Wicked
# 201                 Like That
# 226              Lost In Love
# 240                   We Pray
# 276                 BAND4BAND
# 279                      Fuel
# 285                   It's Up
# 302          California Sober
# 309     I Remember Everything
# 333              Did It First
# 339                 Type Shit
# 352                     Tobey
# 353          Somebody Save Me
# 362                    Habits
# 371                   Lucifer
# 374                 Temporary
# 375                 Road Rage
# 377                   Bad One
# 378               Head Honcho
# 398                Hot Uptown
# 407        I Don't Wanna Wait
# 417               Hell N Back
# 425                  Attitude
# 441                      FE!N
# 488                Cinderella
# 495            II Most Wanted
# 497          One Of The Girls
# 510                 Everybody
# 511  We Still Don't Trust You
# 527               All My Life
# 528             All To Myself
# 529             Show Of Hands
# 530               Young Metro
# 535        We Don't Trust You
# 543  Nobody Knows My Struggle
# 554             Levii's Jeans
# 557                    Tyrant
# 559                Blackbiird
# 560                  Magnetic
# 566                Spaghettii
# 568                 Protector
# 572              Just For Fun
# 574  Sweet * Honey * Buckiin'
# 580                 Slimed In
# 581                  I Luv It
# 584            Claustrophobic
# 599            Surround Sound
# 638           Ordinary Things
# 648           Rich Baby Daddy
# 668                     IDGAF
# 685                      King
# 737                   Lace It
# 746                    Needle
#
#                                                 artist  \
# 10                                Kendrick Lamar & SZA
# 11              Kendrick Lamar Featuring Lefty Gunplay
# 31                          The Weeknd & Playboi Carti
# 58               Cynthia Erivo Featuring Ariana Grande
# 110                           Juice WRLD & Nicki Minaj
# 113  Ariana Grande Featuring Andy Nyman, Courtney-M...
# 201              Future, Metro Boomin & Kendrick Lamar
# 226                            Rod Wave & Be Charlotte
# 240  Coldplay Featuring Little Simz, Burna Boy, Ely...
# 276                             Central Cee & Lil Baby
# 279                                       Eminem & JID
# 285                      Drake, Young Thug & 21 Savage
# 302              Post Malone Featuring Chris Stapleton
# 309               Zach Bryan Featuring Kacey Musgraves
# 333                            Ice Spice & Central Cee
# 339  Future, Metro Boomin, Travis Scott & Playboi C...
# 352                        Eminem, Big Sean & BabyTron
# 353                                Eminem & Jelly Roll
# 362                                Eminem & White Gold
# 371                                 Eminem & Sly Pyper
# 374                               Eminem & Skylar Grey
# 375                     Eminem, Dem Jointz & Sly Pyper
# 377                                Eminem & White Gold
# 378                                    Eminem & Ez Mil
# 398                     Camila Cabello Featuring Drake
# 407                         David Guetta & OneRepublic
# 417                      Bakar Featuring Summer Walker
# 425  Don Toliver Featuring Charlie Wilson & Cash Co...
# 441               Travis Scott Featuring Playboi Carti
# 488                Future, Metro Boomin & Travis Scott
# 495                              Beyonce & Miley Cyrus
# 497                The Weeknd, Jennie & Lily-Rose Depp
# 510                 Nicki Minaj Featuring Lil Uzi Vert
# 511                  Future, Metro Boomin & The Weeknd
# 527                    Future, Metro Boomin & Lil Baby
# 528                  Future, Metro Boomin & The Weeknd
# 529                  Future, Metro Boomin & A$AP Rocky
# 530                  Future, Metro Boomin & The Weeknd
# 535                              Future & Metro Boomin
# 543                              Future & Metro Boomin
# 554                              Beyonce & Post Malone
# 557                             Beyonce & Dolly Parton
# 559  Beyonce, Tanner Adell, Brittney Spencer, Tiera...
# 560                                              ILLIT
# 566                 Beyonce, Linda Martell & Shaboozey
# 568                              Beyonce & Rumi Carter
# 572                             Beyonce & Willie Jones
# 574                                Beyonce & Shaboozey
# 580                              Future & Metro Boomin
# 581                     Camila Cabello & Playboi Carti
# 584                              Future & Metro Boomin
# 599                JID Featuring 21 Savage & Baby Tate
# 638                      Ariana Grande Featuring Nonna
# 648                    Drake Featuring Sexyy Red & SZA
# 668                               Drake Featuring Yeat
# 685                             ¥$: Ye & Ty Dolla $ign
# 737                  Juice WRLD, Eminem & benny blanco
# 746                        Nicki Minaj Featuring Drake
#
#                                                 lyrics orig_lang
# 10   se esse mundo fosse meu hey, número romano set...        pt
# 11   i̇stediğim tek şeydi bir siyah grand national ...        tr
# 31   güneş parlıyor, sona erdi yarın oldu kendini ı...        tr
# 58   เอลฟาบา ช่วยใจเย็นมีสติสักครั้งได้ไหม? อย่าเพิ...        th
# 110  aw merda, oh oh aw merda, oh eu admito, outra ...        pt
# 113  ข่าวดี! นางแม่มดตายแล้ว! ออกมา ออกมา นางไม่อยู...        th
# 201  зажгу косяк в этой суке метро, метро, метро, т...        ru
# 226  largado pra morrer, largado pra morte, continu...        pt
# 240  вау ох тож ми молимося ух я молюся, аби не зда...        uk
# 276  я не в настроении, потому что мой рейс задержа...        ru
# 279  курю марихуану, я катаюсь вокруг приходи на мо...        ru
# 285  ich liebe alle meine freunde denke über das le...        de
# 302  sóbrio na califórnia na rodovia 1 de relance, ...        pt
# 309  安物のウイスキーが俺の心を癒してくれる ビーチタオルが物干し竿で揺れている 俺が君に88年型...        ja
# 333  скажи, детка, ты понимаешь? если он изменяет, ...        ru
# 339  е, е, плуто я не тусуюсь с крысами, это какое-...        ru
# 352  чёрт, бля, чёрт малый, ха тоби магуайра цапнул...        ru
# 353  пап? а? еда здесь продолжай покупать её и прос...        ru
# 362  я долго ждал этого дерьма давно не виделись ду...        ru
# 371  «coup de grâce» — это финальный выстрел прямо ...        ru
# 374  меня часто спрашивают боюсь ли я смерти? честн...        ru
# 375  эт' рэп херня поделена по-бабски, на чьей стор...        ru
# 377  ёу, дре, ага я просто расположусь здесь позвол...        ru
# 378  стараюсь на макс', чтоб не раскрыть свою лично...        ru
# 398  mówisz, że moja miłość na pewno mnie naprawi a...        pl
# 407  lass uns aus heute nacht das wochenende machen...        de
# 417  konntest du sehen, wo mein kopf war, als du mi...        de
# 425  oh, oh fodendo aquela vadia e eu faço ela dize...        pt
# 441  dışarı çık, gece için acele etme, ışığını al j...        tr
# 488  глоток красного, пою для дьявола глоток красно...        ru
# 495  لا نندفع دون تفكير، لكننا لا زلنا شباباً يومًا...        ar
# 497  beni kilitle ve anahtarı fırlat benim en iyi h...        tr
# 510  humm você não é de gangue se deixa coisas pass...        pt
# 511  ela é uma safada gostosa e safada, yeah ainda ...        pt
# 527  wheezy na área é pluto pra sempre yeah durante...        pt
# 528  decolando, decolando, decolando yeah , pluto p...        pt
# 529  сними с него цепи, детка, оставь своих парней ...        ru
# 530  yeah, yeah young metro, young metro, young met...        pt
# 535  фальшем от тебя несёт злостью от тебя несёт зл...        ru
# 543  kimse benim mücadelemi bilmiyor, kimse benim m...        tr
# 554  você me chama de coisinha bonita e eu adoro at...        pt
# 557  cowboy carter tijd om een lucifer aan te steke...        nl
# 559  pássaro negro cantando na calada da noite pegu...        pt
# 560  baby, i'm just trying to play it cool but i ju...        fr
# 566  gatunki to zabawny koncept, nie sądzisz? tak, ...        pl
# 568  мама, можно я послушаю колыбельную? пожалуйста...        ru
# 572  ik ga er helemaal voor, gewoon voor de lol, ik...        nl
# 574  rozpadam się na kawałki za każdym razem, gdy c...        pl
# 580  eu simplesmente tô com aquele slime, tô de vol...        pt
# 581  supersônica , em sua órbita e eu sou gostosa ,...        pt
# 584  der ganze andere scheiß ist müll, das ist das,...        de
# 599  jag vet att jag inte har råd att stanna för et...        sv
# 638  hmm felbonthatjuk az összes pezsgőt kaliforniá...        hu
# 648  ist das alles ich könnte genug sein ist das al...        de
# 668  вечное брожение в темноте из тьмы во мрак во в...        ru
# 685                                                  (        un
# 737  е, эй, м-м роллю, завязял это, ем немного, что...        ru
# 746  quero dizer, não sei se gosto de garotas, vi s...        pt

# %% [markdown]
# All of these songs are english songs. meaning - when we received these lyrics from genius, we got translations - we will need to translate them back or try another way to retrieve the lyrics

# %%
song = df[df["orig_lang"] == "es"].iloc[0]

song["lyrics"]
# Out:
# "deck the halls with boughs of holly fa-la-la-la-la, la-la-la-la 'tis the season to be jolly fa-la-la-la-la, la-la-la-la don we now our gay apparel fa-la-la, la-la-la, la-la-la troll the ancient yuletide carol fa-la-la-la-la, la-la-la-la fa-la-la, la-la-la, la-la-la fa-la-la, la-la-la, la-la-la fa-la-la, la-la-la, la-la-la fa-la-la, la-la-la, la-la-la see the blazing yule before us fa-la-la-la-la, la-la-la-la strike the harp and join the chorus fa-la-la-la-la, la-la-la-la follow me in merry measure fa-la-la-la-la, la-la-la-la while i tell of yuletide treasure fa-la-la-la-la, la-la-la-la fa-la-la-la-la, la-la-la-la"

# %% [markdown]
# We can also see here an example of wrong language detection. the above song is a christmas song sang in english, but was detected as spanish. this is due to a lot of filler words.
#
# To counter that - we will try to detect language based on unique words, rather than the text as a whole

# %%
en_stop = spacy.lang.en.stop_words.STOP_WORDS
PUNCT_RE = re.compile(r"[^a-z\s]")

def unique_word_snippet(text: str, max_tokens: int = 250) -> str:
    """
    Return a whitespace-separated string containing **unique** words
    in first-appearance order, up to `max_tokens` tokens.
    """
    # 1. basic clean
    # txt = PUNCT_RE.sub(" ", text.lower())
    words = text.split()
    
    # 2. deduplicate but keep order
    seen, uniq = set(), []
    for w in words:
        if w not in seen:
            uniq.append(w)
            seen.add(w)
        if len(uniq) >= max_tokens:
            break
    return " ".join(uniq)

# %%
def detect_lang_unique(text: str) -> str:
    snippet = unique_word_snippet(text)
    if not snippet.strip():          # empty after cleaning
        return "un"
    
    try:
        lang = detect(snippet)
    except Exception:
        return "un"
    
    return lang

# %%
df["orig_lang"] = df["lyrics"].progress_apply(detect_lang_unique)

df["orig_lang"].value_counts()
# Out:
#   0%|          | 0/758 [00:00<?, ?it/s]
# orig_lang
# en    644
# es     55
# ru     19
# pt     15
# tr      5
# de      5
# pl      3
# th      2
# nl      2
# ar      1
# hu      1
# sv      1
# id      1
# ko      1
# ja      1
# uk      1
# un      1
# Name: count, dtype: int64

# %%
# ──────────────────────────────────────────────
# 4  |  Translate non-English to English
# ──────────────────────────────────────────────
translator = GoogleTranslator(source="auto", target="en")

# Google unofficial endpoint: max 5 req / s & 5 000 chars / call.
# We'll translate in ≤4 000-char chunks to be safe.
MAX_CHARS = 4000
SLEEP_BETWEEN_REQ = 0.25        # 4 requests/sec  ➜ stay under 5 r/s

def safe_translate(text: str, src_lang: str) -> str:
    """
    Translate `text` to English unless it's already English.
    Handles 429 & 5 000-char limits gracefully.
    """
    if src_lang == "en" or not text.strip():
        return text

    if src_lang == "un":
        return ""

    # Split long lyrics into <= MAX_CHARS pieces at line breaks
    parts, buf = [], ""
    for line in text.splitlines():
        if len(buf) + len(line) + 1 > MAX_CHARS:
            parts.append(buf)
            buf = line + "\n"
        else:
            buf += line + "\n"
    parts.append(buf)

    translated_parts = []
    for p in parts:
        retry, ok = 0, False
        while not ok and retry < 5:
            try:
                translated_parts.append(translator.translate(p))
                ok = True
            except Exception as e:
                # Handle Google 429 or random failures
                wait = 2 ** retry        # exponential back-off: 1,2,4,8,16 s
                logging.warning(f"MT error ({e}); retrying in {wait}s")
                time.sleep(wait)
                retry += 1
        if not ok:                      # give up – keep original chunk
            translated_parts.append(p)
        time.sleep(SLEEP_BETWEEN_REQ)   # rate-limit

    return "\n".join(translated_parts)

# %% [markdown]
# Let's test translating with a single song first

# %%
song = df[df["orig_lang"] == "es"].iloc[0]

song["lyrics"]
# Out:
# "siento un vacío muy frío por dentro, mi amor cuando te fuiste, te robaste mi corazón me quedé loco de tanto pensar y pensar me iré al infierno, pero me tengo que vengar quiero manchar el vestido blanco de rojo sé que el altar dе dios es santo, pero, mi amor cien invitados y todos tеndrán que mirar que nuestro amor va al más allá quiero que bailemos juntos en el cielo, el infierno, pero sin ese puto el que te ha apartado todo este tiempo de mí al inconsciente que hizo que no fueras pa' mí danza, una danza eterna pero me voy contigo, pero nos vamos juntos llevo tres noches malditas sin poder dormir solo pensando y pensando que eres para mí ¡uh! me despido de ti para siempre, chiquitita ahí le va para todos los que traen el corazón roto uh y su compa óscar maydon fuerza regida camino lento, me duele la respiración a mil por hora latidos de mi corazón en el pasillo me vienen recuerdos, flashbacks prometimos que los dos iríamos al altar te quitó el velo, aceptaste y luego te besó ya has consumado los votos sagrados, mi amor un frío muy intenso se llevó todo mi ser ya no hay razón pa' estar de pie quiero que bailemos juntos en el cielo, el infierno, pero sin ese puto al que te ha apartado todo este tiempo de mí al inconsciente que hizo que no fueras pa' mí danza, una danza eterna pero me voy contigo, pero nos vamos juntos llevo tres noches malditas sin poder dormir solo pensando y pensando que eras para mí miro cómo brillan tus ojos me resigno perderte y esta vez para siempre me arrepentí de quitarte tu felicidad te dejaré una familia puedas comenzar me despido, me despido pa' siempre y te deseo suerte, y bendigo mi muerte se la dedico al amor que nunca funcionó a la persona que roto tiene el corazón"

# %%
trans = safe_translate(song["lyrics"], song["orig_lang"])

trans
# Out:
# 'I feel a very cold emptiness inside, my love when you left, you stole my heart I was crazy about thinking and thinking I will go to hell, but I have to avenge I want to stain the white red dress I know that the altar of God is holy, but, my love a hundred guests and all will have to look that our love goes to the beyond I want us to dance together in the sky, hell That you were not for my dance, an eternal dance but I leave with you, but we go together I have three cursed nights without being able to sleep just thinking and thinking that you are for me Uh! I say goodbye to you forever, little girl there goes for everyone who brings the broken heart and his company Óscar Maydon Fortid Intense, my being took all my being, there is no reason to be standing in the sky, hell, but without that fucking to which all this time from me has separated to the unconscious that did not force me dancing, an eternal dance but I go with you, but we go together I have three damn nights without being able to sleep just thinking and thinking that you were for me to look like your eyes. I repent to take away your happiness I will leave you a family you can start, I say goodbye, I say goodbye for me and I wish you luck, and I bless my death I dedicate it to love that never worked to the person who broken has the heart'

# %% [markdown]
# **Now let's translate all the songs**

# %%
for idx, row in df.iterrows():
    if pd.isna(row["lyrics_en"]):
        df.at[idx, "lyrics_en"] = safe_translate(row["lyrics"], row["orig_lang"])
        if row["orig_lang"] != "en":
            print(f"translated song {row['title']} from {row['orig_lang']}")
# Out:
# translated song King from un
# translated song Que Onda from es
# translated song Y Lloro from es
# translated song First Love from es
# translated song El Amor de Su Vida from es
# translated song Lace It from ru
# translated song Mi Ex Tenia Razon from es
# translated song Rompe La Dompe from es
# translated song Sabor Fresa from es
# translated song Qlona from es
# translated song Needle from pt
# translated song Amargura from es

# %%
translated_songs = df[df["orig_lang"] != "en"]

translated_songs[["artist", "title", "orig_lang", "lyrics", "lyrics_en"]]
# Out:
#                                      artist            title orig_lang  \
# 10                     Kendrick Lamar & SZA           Luther        pt
# 11   Kendrick Lamar Featuring Lefty Gunplay           TV Off        tr
# 31               The Weeknd & Playboi Carti         Timeless        tr
# 58    Cynthia Erivo Featuring Ariana Grande  Defying Gravity        th
# 60             Oscar Maydon & Fuerza Regida          Tu Boda        es
# ..                                      ...              ...       ...
# 740     Peso Pluma, Junior H & Oscar Maydon   Rompe La Dompe        es
# 743                           Fuerza Regida      Sabor Fresa        es
# 745                    Karol G & Peso Pluma            Qlona        es
# 746             Nicki Minaj Featuring Drake           Needle        pt
# 749                                 Karol G         Amargura        es
#
#                                                 lyrics  \
# 10   se esse mundo fosse meu hey, número romano set...
# 11   i̇stediğim tek şeydi bir siyah grand national ...
# 31   güneş parlıyor, sona erdi yarın oldu kendini ı...
# 58   เอลฟาบา ช่วยใจเย็นมีสติสักครั้งได้ไหม? อย่าเพิ...
# 60   siento un vacío muy frío por dentro, mi amor c...
# ..                                                 ...
# 740  rompe la dom pe la paca nunca se acaba, farand...
# 743  mesero, traiga champagne que quiero complacer ...
# 745  ayer te vi solita, esa carita bonita diablo, q...
# 746  quero dizer, não sei se gosto de garotas, vi s...
# 749  si te dicen que yo me estoy curando, es la ver...
#
#                                              lyrics_en
# 10   If this world were my hey, Roman number seven,...
# 11   The only thing I said was a black Grand Nation...
# 31   The sun shines, ended tomorrow in the light, i...
# 58   เอลฟาบา ช่วยใจเย็นมีสติสักครั้งได้ไหม? อย่าเพิ...
# 60   I feel a very cold emptiness inside, my love w...
# ..                                                 ...
# 740  Break the dom pe the paca never ends, pharandu...
# 743  Waiter, brought champagne that I want to pleas...
# 745  Yesterday I saw you alone, that little little ...
# 746  I mean, I don't know if I like girls, I saw Sh...
# 749  If they tell you that I am healing, it is the ...
#
# [114 rows x 5 columns]

# %% [markdown]
# ## Exporting the df for further use

# %%
OUT_DIR = Path("../data/processed")
OUT_DIR.mkdir(exist_ok=True)

OUT_FILE  = OUT_DIR / "hot100_translated.xlsx"
df.to_excel(OUT_FILE, index=False, engine="openpyxl")

print(f"✓ Saved translated corpus → {OUT_FILE.resolve()}")
# Out:
# ✓ Saved translated corpus → C:\Users\royic\OneDrive\Desktop\לימודים\שנה ג\סמסטר ב\טקסט כנתונים\billboard-100-lyrics-analysis\data\processed\hot100_translated.xlsx
